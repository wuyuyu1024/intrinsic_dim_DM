# %%
import sys
import os
sys.path.append('../dbm_evaluation')
sys.path.append('../DeepView')

from map_evaluation import P_wrapper, Evaluator, NNinv_keras, NNinv_torch, MapBuilder


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
#import knn and decision tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
# import make blobs
from sklearn.datasets import make_blobs
from sklearn.datasets import load_iris

from scipy.spatial import Delaunay
from scipy.interpolate import Rbf

# date
from datetime import datetime

from umap import UMAP
from sklearn.manifold import TSNE, MDS

from tqdm import tqdm

from ssnp import SSNP

from lamp import Pinv_ilamp
from NNinv import NNinv_torch
from rbf_inv import RBFinv
from multilateration import MDSinv
# date
# Out:
# WARNING:tensorflow:From C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
# c:\Users\yuwan\workspace\intrinsic_dim_DM\../DeepView\deepview\Stochastic_Embedding.py:187: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit(parallel=True)

# %%
# # import PCA
# from sklearn.decomposition import PCA

# blob = make_blobs(n_samples=1000, n_features=1000, centers=3, cluster_std=1.0, center_box=(-10.0, 10.0), shuffle=True, random_state=1)
# pca = PCA(n_components=2)
# pca.fit(blob[0])
# pca_blob = pca.transform(blob[0])

# plt.scatter(pca_blob[:,0], pca_blob[:,1], c=blob[1], cmap='viridis')

# %%
# make my own color map
# cmap = colors.ListedColormap(['#888E88', '#3322DD', 'gold' ], name='custom') # '#3322DD' '#EEDD22'
cmap = colors.ListedColormap(['#22DDDD', '#5566DD', 'gold' ], name='custom') # '#3322DD' '#EEDD22'
# cmap = 'jet'

# %%
## Load iris data

iris = load_iris()
# ind = y != 0
# ind = np.where(iris.target != 1)[0]
# y = y - 1
# X = iris.data[ind, 1:]
# y = iris.target[ind]
X = iris.data[:, 1:]
y = iris.target

print(X.shape, y.shape)
blob0 = [X, y]
# visualize
plt.scatter(X[:,2], X[:,0], c=y, cmap='viridis')

X.shape

#### blob

# blob0 = make_blobs(n_samples=150, n_features=3, centers=2, cluster_std=0.8, random_state=42)
# # blob0 = make_blobs(n_samples=150, n_features=3, centers=5, cluster_std=1.2, random_state=6666)
# y = blob0[1]
# X = blob0[0]
# Out:
# (150, 3) (150,)
# (150, 3)

# %%
# %matplotlib widget

# plot the blobs in 3D"
fig_3d = plt.figure()
ax_3d = fig_3d.add_subplot(111, projection='3d')
# ax.view_init() what is the default view? type help(ax.view_init)
# help(ax.view_init)
CMAP = cmap#"custom" #'PiYG'
pinot_clor_map = cm.get_cmap(CMAP)
ponit_clor = pinot_clor_map(y/y.max())

#####
lazy_scaler = MinMaxScaler()
blob0 = list(blob0)
blob0[0] = lazy_scaler.fit_transform(blob0[0])
#####

ax_3d.scatter(blob0[0][:,0], blob0[0][:,1], blob0[0][:,2], c=ponit_clor, )#cmap='tab10', )
# Out:
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\3765452290.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   pinot_clor_map = cm.get_cmap(CMAP)

# %%
class Simple_P_wrapper:
    def __init__(self, P, Pinv):
        self.P = P
        self.Pinv = Pinv
    def __call__(self, x):
        return self.P(x)
    def transform(self, x):
        return self.P.transform(x)
    def inverse_transform(self, x):
        return self.Pinv.transform(x)

    def fit(self, x, y=None, clf=None):
        # self.P.fit(x)
        self.X2d = self.P.fit_transform(x)
        self.Pinv.fit(self.X2d, x )
        return self

p = UMAP(n_components=2, random_state=43, n_neighbors=30, min_dist=0.9)
Pinv = NNinv_torch(dims=[2048]*4)
proj = Simple_P_wrapper(p, Pinv)
# Out:
# device:  cuda:0

# %%
# scaler = MinMaxScaler()
# X = scaler.fit_transform(blob0[0])
X = blob0[0]
y = blob0[1]

# NNinv_keras = 0
# NNinv_torch = 1
# deepview = 0
# ssnp = 0

# name_list = ['NNinv_keras', 'NNinv_torch', 'deepview', 'ssnp']
# #get the none zero name
# name_plot = [name_list[i] for i in [NNinv_keras, NNinv_torch, deepview, ssnp] if i != 0][0]

# # ssnp = SSNP(patience=5, opt='adam', bottleneck_activation='linear', verbose=0)
# proj = P_wrapper(NNinv_Keras=NNinv_keras, NNinv_Torch=NNinv_torch, deepview=deepview, ssnp=ssnp)
clf = linear_model.LogisticRegression()
# clf = SVC(probability=True)
# clf = KNeighborsClassifier()
# clf = DecisionTreeClassifier()
# clf = RandomForestClassifier()
P = MDS(n_components=2, random_state=0)

# dbm = P_wrapper(NNinv_Torch=1, deepview=0, ssnp=0, NNinv_Keras=0)
# ssnp = P_wrapper(NNinv_Keras=0, NNinv_Torch=0, deepview=0, ssnp=1)
DV = P_wrapper(NNinv_Keras=0, NNinv_Torch=0, deepview=1, ssnp=0)


# Pinv = NNinv_torch(dims=[2048]*4)

ilamp = Simple_P_wrapper(P, Pinv_ilamp())
dbm = Simple_P_wrapper(P, NNinv_torch())
ssnp = SSNP(bottleneck_activation='linear', )
mdsinv_rand = Simple_P_wrapper(P, MDSinv())
# mdsinv_near = Simple_P_wrapper(P, MDSinv(point_selection='nearest'))
rbf_inv = Simple_P_wrapper(P, RBFinv())

clf.fit(X, y)

DV.fit(X, y, clf, lam=0.65)
dbm.fit(X, y, clf)
ssnp.fit(X, y)
ilamp.fit(X, y, clf)
mdsinv_rand.fit(X, y, clf)
# mdsinv_near.fit(X, y, clf)
rbf_inv.fit(X, y, clf)
# Out:
# device:  cuda:0
# WARNING:tensorflow:From C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# 100%|██████████| 150/150 [00:00<00:00, 1236.98it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# done
# fitting time:  7.099790096282959
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Early stopping at epoch 56
# WARNING:tensorflow:From C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - 2s 71ms/step - loss: 3.7256 - main_output_loss: 1.0972 - decoder_output_loss: 0.6925 - main_output_accuracy: 0.4085 - decoder_output_accuracy: 0.4014 - val_loss: 3.7014 - val_main_output_loss: 1.1150 - val_decoder_output_loss: 0.6956 - val_main_output_accuracy: 0.0000e+00 - val_decoder_output_accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 17ms/step - loss: 3.6137 - main_output_loss: 1.0595 - decoder_output_loss: 0.6872 - main_output_accuracy: 0.6901 - decoder_output_accuracy: 0.7183 - val_loss: 3.6046 - val_main_output_loss: 1.0851 - val_decoder_output_loss: 0.6963 - val_main_output_accuracy: 0.5000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 3.4227 - main_output_loss: 0.9490 - decoder_output_loss: 0.6736 - main_output_accuracy: 0.7535 - decoder_output_accuracy: 0.7606 - val_loss: 3.3546 - val_main_output_loss: 0.9115 - val_decoder_output_loss: 0.6854 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 4/100
# 5/5 [==============================] - 0s 13ms/step - loss: 3.0916 - main_output_loss: 0.7220 - decoder_output_loss: 0.6342 - main_output_accuracy: 0.6549 - decoder_output_accuracy: 0.7746 - val_loss: 2.9485 - val_main_output_loss: 0.6061 - val_decoder_output_loss: 0.6479 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7745 - main_output_loss: 0.5257 - decoder_output_loss: 0.5757 - main_output_accuracy: 0.6479 - decoder_output_accuracy: 0.7746 - val_loss: 2.6363 - val_main_output_loss: 0.4025 - val_decoder_output_loss: 0.6002 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 6/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6011 - main_output_loss: 0.4316 - decoder_output_loss: 0.5569 - main_output_accuracy: 0.7465 - decoder_output_accuracy: 0.7746 - val_loss: 2.6170 - val_main_output_loss: 0.4270 - val_decoder_output_loss: 0.6160 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 7/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.4933 - main_output_loss: 0.3682 - decoder_output_loss: 0.5715 - main_output_accuracy: 0.8662 - decoder_output_accuracy: 0.7746 - val_loss: 2.4679 - val_main_output_loss: 0.3600 - val_decoder_output_loss: 0.5922 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 8/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.3687 - main_output_loss: 0.3090 - decoder_output_loss: 0.5637 - main_output_accuracy: 0.9296 - decoder_output_accuracy: 0.7746 - val_loss: 2.4111 - val_main_output_loss: 0.3752 - val_decoder_output_loss: 0.5766 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.0000e+00
# Epoch 9/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.2442 - main_output_loss: 0.2554 - decoder_output_loss: 0.5484 - main_output_accuracy: 0.9225 - decoder_output_accuracy: 0.7746 - val_loss: 2.5180 - val_main_output_loss: 0.5218 - val_decoder_output_loss: 0.5908 - val_main_output_accuracy: 0.7500 - val_decoder_output_accuracy: 0.3750
# Epoch 10/100
# 5/5 [==============================] - 0s 9ms/step - loss: 2.1575 - main_output_loss: 0.2207 - decoder_output_loss: 0.5495 - main_output_accuracy: 0.9085 - decoder_output_accuracy: 0.6620 - val_loss: 1.9673 - val_main_output_loss: 0.0450 - val_decoder_output_loss: 0.5677 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 10ms/step - loss: 2.0641 - main_output_loss: 0.1812 - decoder_output_loss: 0.5457 - main_output_accuracy: 0.9366 - decoder_output_accuracy: 0.5845 - val_loss: 2.2694 - val_main_output_loss: 0.3886 - val_decoder_output_loss: 0.5752 - val_main_output_accuracy: 0.8750 - val_decoder_output_accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.9705 - main_output_loss: 0.1376 - decoder_output_loss: 0.5435 - main_output_accuracy: 0.9366 - decoder_output_accuracy: 0.7958 - val_loss: 1.8638 - val_main_output_loss: 0.0354 - val_decoder_output_loss: 0.5693 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9014 - main_output_loss: 0.1165 - decoder_output_loss: 0.5418 - main_output_accuracy: 0.9507 - decoder_output_accuracy: 0.8169 - val_loss: 1.8150 - val_main_output_loss: 0.0352 - val_decoder_output_loss: 0.5660 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 14/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.8373 - main_output_loss: 0.0991 - decoder_output_loss: 0.5397 - main_output_accuracy: 0.9507 - decoder_output_accuracy: 0.8592 - val_loss: 1.7574 - val_main_output_loss: 0.0238 - val_decoder_output_loss: 0.5634 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.8221 - main_output_loss: 0.1261 - decoder_output_loss: 0.5406 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8380 - val_loss: 1.8728 - val_main_output_loss: 0.1824 - val_decoder_output_loss: 0.5625 - val_main_output_accuracy: 0.8750 - val_decoder_output_accuracy: 0.8750
# Epoch 16/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.7984 - main_output_loss: 0.1456 - decoder_output_loss: 0.5391 - main_output_accuracy: 0.9366 - decoder_output_accuracy: 0.8662 - val_loss: 1.6580 - val_main_output_loss: 0.0084 - val_decoder_output_loss: 0.5617 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7530 - main_output_loss: 0.1413 - decoder_output_loss: 0.5378 - main_output_accuracy: 0.9437 - decoder_output_accuracy: 0.8451 - val_loss: 1.6973 - val_main_output_loss: 0.0875 - val_decoder_output_loss: 0.5612 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 18/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.6670 - main_output_loss: 0.0939 - decoder_output_loss: 0.5375 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8451 - val_loss: 1.5913 - val_main_output_loss: 0.0205 - val_decoder_output_loss: 0.5592 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6199 - main_output_loss: 0.0843 - decoder_output_loss: 0.5367 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8662 - val_loss: 1.6364 - val_main_output_loss: 0.1006 - val_decoder_output_loss: 0.5602 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 20/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5853 - main_output_loss: 0.0842 - decoder_output_loss: 0.5375 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8803 - val_loss: 1.5293 - val_main_output_loss: 0.0286 - val_decoder_output_loss: 0.5594 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5455 - main_output_loss: 0.0790 - decoder_output_loss: 0.5369 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8521 - val_loss: 1.5107 - val_main_output_loss: 0.0437 - val_decoder_output_loss: 0.5590 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4983 - main_output_loss: 0.0648 - decoder_output_loss: 0.5368 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8451 - val_loss: 1.4637 - val_main_output_loss: 0.0284 - val_decoder_output_loss: 0.5595 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 23/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.4653 - main_output_loss: 0.0639 - decoder_output_loss: 0.5366 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8521 - val_loss: 1.4397 - val_main_output_loss: 0.0361 - val_decoder_output_loss: 0.5589 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 24/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.4328 - main_output_loss: 0.0624 - decoder_output_loss: 0.5362 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8451 - val_loss: 1.3994 - val_main_output_loss: 0.0261 - val_decoder_output_loss: 0.5588 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.3992 - main_output_loss: 0.0581 - decoder_output_loss: 0.5369 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8521 - val_loss: 1.3620 - val_main_output_loss: 0.0185 - val_decoder_output_loss: 0.5581 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 10ms/step - loss: 1.3835 - main_output_loss: 0.0717 - decoder_output_loss: 0.5363 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8239 - val_loss: 1.3407 - val_main_output_loss: 0.0256 - val_decoder_output_loss: 0.5580 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.3353 - main_output_loss: 0.0517 - decoder_output_loss: 0.5361 - main_output_accuracy: 0.9859 - decoder_output_accuracy: 0.8521 - val_loss: 1.2996 - val_main_output_loss: 0.0101 - val_decoder_output_loss: 0.5597 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.3330 - main_output_loss: 0.0770 - decoder_output_loss: 0.5356 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8592 - val_loss: 1.2710 - val_main_output_loss: 0.0068 - val_decoder_output_loss: 0.5609 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3053 - main_output_loss: 0.0750 - decoder_output_loss: 0.5359 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8592 - val_loss: 1.2570 - val_main_output_loss: 0.0205 - val_decoder_output_loss: 0.5588 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 30/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2825 - main_output_loss: 0.0766 - decoder_output_loss: 0.5369 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8451 - val_loss: 1.2202 - val_main_output_loss: 0.0075 - val_decoder_output_loss: 0.5593 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2565 - main_output_loss: 0.0759 - decoder_output_loss: 0.5357 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8521 - val_loss: 1.2134 - val_main_output_loss: 0.0248 - val_decoder_output_loss: 0.5591 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 32/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2101 - main_output_loss: 0.0532 - decoder_output_loss: 0.5354 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8592 - val_loss: 1.1772 - val_main_output_loss: 0.0094 - val_decoder_output_loss: 0.5610 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 33/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.2188 - main_output_loss: 0.0842 - decoder_output_loss: 0.5355 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8380 - val_loss: 1.1886 - val_main_output_loss: 0.0433 - val_decoder_output_loss: 0.5607 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.6250
# Epoch 34/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.1842 - main_output_loss: 0.0706 - decoder_output_loss: 0.5365 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8451 - val_loss: 1.1304 - val_main_output_loss: 0.0062 - val_decoder_output_loss: 0.5607 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.1783 - main_output_loss: 0.0863 - decoder_output_loss: 0.5357 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8451 - val_loss: 1.1276 - val_main_output_loss: 0.0257 - val_decoder_output_loss: 0.5590 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 36/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.1247 - main_output_loss: 0.0529 - decoder_output_loss: 0.5358 - main_output_accuracy: 0.9859 - decoder_output_accuracy: 0.8380 - val_loss: 1.1086 - val_main_output_loss: 0.0278 - val_decoder_output_loss: 0.5577 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 37/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.1148 - main_output_loss: 0.0629 - decoder_output_loss: 0.5354 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8592 - val_loss: 1.0831 - val_main_output_loss: 0.0213 - val_decoder_output_loss: 0.5577 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0915 - main_output_loss: 0.0588 - decoder_output_loss: 0.5349 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8451 - val_loss: 1.0710 - val_main_output_loss: 0.0273 - val_decoder_output_loss: 0.5578 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 39/100
# 5/5 [==============================] - 0s 25ms/step - loss: 1.0697 - main_output_loss: 0.0547 - decoder_output_loss: 0.5354 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8380 - val_loss: 1.0466 - val_main_output_loss: 0.0191 - val_decoder_output_loss: 0.5592 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 40/100
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0770 - main_output_loss: 0.0790 - decoder_output_loss: 0.5357 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8380 - val_loss: 1.0228 - val_main_output_loss: 0.0127 - val_decoder_output_loss: 0.5588 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0561 - main_output_loss: 0.0743 - decoder_output_loss: 0.5364 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8521 - val_loss: 1.0219 - val_main_output_loss: 0.0282 - val_decoder_output_loss: 0.5590 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 42/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0818 - main_output_loss: 0.1162 - decoder_output_loss: 0.5365 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8521 - val_loss: 0.9882 - val_main_output_loss: 0.0102 - val_decoder_output_loss: 0.5594 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 43/100
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0313 - main_output_loss: 0.0825 - decoder_output_loss: 0.5359 - main_output_accuracy: 0.9437 - decoder_output_accuracy: 0.8662 - val_loss: 1.0069 - val_main_output_loss: 0.0452 - val_decoder_output_loss: 0.5588 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 44/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9884 - main_output_loss: 0.0559 - decoder_output_loss: 0.5347 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8380 - val_loss: 0.9649 - val_main_output_loss: 0.0188 - val_decoder_output_loss: 0.5578 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9696 - main_output_loss: 0.0518 - decoder_output_loss: 0.5345 - main_output_accuracy: 0.9859 - decoder_output_accuracy: 0.8592 - val_loss: 0.9828 - val_main_output_loss: 0.0510 - val_decoder_output_loss: 0.5578 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 46/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9647 - main_output_loss: 0.0613 - decoder_output_loss: 0.5342 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8380 - val_loss: 0.9367 - val_main_output_loss: 0.0168 - val_decoder_output_loss: 0.5593 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9516 - main_output_loss: 0.0606 - decoder_output_loss: 0.5350 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8451 - val_loss: 0.9275 - val_main_output_loss: 0.0221 - val_decoder_output_loss: 0.5579 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9302 - main_output_loss: 0.0530 - decoder_output_loss: 0.5343 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8380 - val_loss: 0.9186 - val_main_output_loss: 0.0256 - val_decoder_output_loss: 0.5582 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 49/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9192 - main_output_loss: 0.0546 - decoder_output_loss: 0.5341 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8451 - val_loss: 0.8976 - val_main_output_loss: 0.0155 - val_decoder_output_loss: 0.5594 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 50/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9063 - main_output_loss: 0.0535 - decoder_output_loss: 0.5343 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8310 - val_loss: 0.8849 - val_main_output_loss: 0.0141 - val_decoder_output_loss: 0.5598 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 51/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8959 - main_output_loss: 0.0549 - decoder_output_loss: 0.5341 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8451 - val_loss: 0.8781 - val_main_output_loss: 0.0192 - val_decoder_output_loss: 0.5593 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 52/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8776 - main_output_loss: 0.0481 - decoder_output_loss: 0.5337 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8451 - val_loss: 0.8577 - val_main_output_loss: 0.0099 - val_decoder_output_loss: 0.5591 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 53/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8874 - main_output_loss: 0.0686 - decoder_output_loss: 0.5340 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8380 - val_loss: 0.8467 - val_main_output_loss: 0.0093 - val_decoder_output_loss: 0.5593 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 54/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9182 - main_output_loss: 0.1082 - decoder_output_loss: 0.5354 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8310 - val_loss: 0.8451 - val_main_output_loss: 0.0188 - val_decoder_output_loss: 0.5585 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 55/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8584 - main_output_loss: 0.0597 - decoder_output_loss: 0.5345 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8451 - val_loss: 0.8384 - val_main_output_loss: 0.0226 - val_decoder_output_loss: 0.5580 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 56/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8359 - main_output_loss: 0.0475 - decoder_output_loss: 0.5339 - main_output_accuracy: 0.9789 - decoder_output_accuracy: 0.8380 - val_loss: 0.8176 - val_main_output_loss: 0.0104 - val_decoder_output_loss: 0.5588 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8431 - main_output_loss: 0.0644 - decoder_output_loss: 0.5335 - main_output_accuracy: 0.9718 - decoder_output_accuracy: 0.8451 - val_loss: 0.8577 - val_main_output_loss: 0.0608 - val_decoder_output_loss: 0.5578 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 58/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8439 - main_output_loss: 0.0739 - decoder_output_loss: 0.5341 - main_output_accuracy: 0.9577 - decoder_output_accuracy: 0.8310 - val_loss: 0.7980 - val_main_output_loss: 0.0081 - val_decoder_output_loss: 0.5594 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8417 - main_output_loss: 0.0802 - decoder_output_loss: 0.5340 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8380 - val_loss: 0.8163 - val_main_output_loss: 0.0348 - val_decoder_output_loss: 0.5597 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.5000
# Epoch 60/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8442 - main_output_loss: 0.0902 - decoder_output_loss: 0.5351 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8239 - val_loss: 0.7914 - val_main_output_loss: 0.0176 - val_decoder_output_loss: 0.5601 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.6250
# Epoch 61/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8339 - main_output_loss: 0.0878 - decoder_output_loss: 0.5349 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8380 - val_loss: 0.7834 - val_main_output_loss: 0.0185 - val_decoder_output_loss: 0.5590 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 62/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8577 - main_output_loss: 0.1183 - decoder_output_loss: 0.5363 - main_output_accuracy: 0.9507 - decoder_output_accuracy: 0.8310 - val_loss: 0.8081 - val_main_output_loss: 0.0505 - val_decoder_output_loss: 0.5593 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 63/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8383 - main_output_loss: 0.1078 - decoder_output_loss: 0.5345 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8310 - val_loss: 0.7605 - val_main_output_loss: 0.0098 - val_decoder_output_loss: 0.5595 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8518 - main_output_loss: 0.1268 - decoder_output_loss: 0.5366 - main_output_accuracy: 0.9366 - decoder_output_accuracy: 0.8521 - val_loss: 0.9947 - val_main_output_loss: 0.2440 - val_decoder_output_loss: 0.5670 - val_main_output_accuracy: 0.8750 - val_decoder_output_accuracy: 0.5000
# Epoch 65/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.8258 - main_output_loss: 0.1084 - decoder_output_loss: 0.5359 - main_output_accuracy: 0.9437 - decoder_output_accuracy: 0.8451 - val_loss: 0.7516 - val_main_output_loss: 0.0137 - val_decoder_output_loss: 0.5606 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 1.0000
# Epoch 66/100
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8062 - main_output_loss: 0.0774 - decoder_output_loss: 0.5515 - main_output_accuracy: 0.9688 - decoder_output_accuracy: 0.8438Restoring model weights from the end of the best epoch: 63.
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7845 - main_output_loss: 0.0750 - decoder_output_loss: 0.5346 - main_output_accuracy: 0.9648 - decoder_output_accuracy: 0.8521 - val_loss: 0.8330 - val_main_output_loss: 0.1013 - val_decoder_output_loss: 0.5612 - val_main_output_accuracy: 1.0000 - val_decoder_output_accuracy: 0.8750
# Epoch 66: early stopping
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# r:  (150, 150)
# coefficients:  (150, 3)
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
# import tensorflow as tf
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
# if len(physical_devices) > 0:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)


# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# ! pip list | grep tensor

# %%
# fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
# map_builder = MapBuilder(clf, dbm, X, y, grid=100)
# ax_grad = map_builder.plot_gradient_map(ax=ax1)
# dv_map = map_builder.plot_prob_map(ax=ax2)
# plt.show()

# %%
X_2d = ssnp.transform(blob0[0])
# scale the data to be between 0 and 1
# scaler2d = MinMaxScaler()
# X_2d = scaler2d.fit_transform(X_2d)


fig, ax = plt.subplots(figsize=(5,5) )
ax.scatter(X_2d[:,0], X_2d[:,1], c=ponit_clor)
# no ticks
ax.set_xticks([])
ax.set_yticks([])
# suqare aspect ratio`
# ax.set_aspect('equal')
# make directory if it doesn't exist
# if not os.path.exists('./figures/inlustrate_dbm'):
#     os.makedirs('./figures/inlustrate_dbm')
# fig.savefig('./figures/inlustrate_dbm/2d_1')
# Out:
# 5/5 [==============================] - 0s 0s/step
# []

# %%
# %matplotlib widget
GRID = 20
# CMAP = 'tab10'

# %%
def plot_inverse_map(P_inv, GRID=GRID, clf=clf, ax=None, CMAP=CMAP, single_color=False):

    

    try:
        X_2d = P_inv.X2d
    except:
        X_2d = P_inv.transform(blob0[0])


    xx, yy = np.meshgrid(np.linspace(X_2d[:,0].min(), X_2d[:,0].max(), GRID), np.linspace(X_2d[:,1].min(), X_2d[:,1].max(), GRID))
    XY = np.c_[xx.ravel(), yy.ravel()]
    XY_3d = P_inv.inverse_transform(XY)
    # XY_3d = scaler.inverse_transform(XY_3d)
    labels = clf.predict(XY_3d)
    ## grids with labels
    tab10 = cm.get_cmap(CMAP)
    labels_color = tab10(labels/labels.max())
    labels_color_2d = tab10(labels.reshape(GRID,GRID)/labels.max())
    # set alpha to 0.5
    labels_color_2d[:, : ,3] = 0.7
    # print(labels_color_2d.shape)
    # print(XY_3d[:,0].reshape(GRID,GRID).shape)
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')

    # visual_scaler = MinMaxScaler(0, GRID)

    # # ax_grid_dbm.scatter(XY_3d[:,0], XY_3d[:,1], XY_3d[:,2], c=labels_color[:], alpha=0.9, marker='+', cmap = 'tab10', s=100)
    # ax.scatter(blob0[0][:,0], blob0[0][:,1], blob0[0][:,2], c=blob0[1], cmap='tab10', ec='k', s=7, linewidth=0.1, alpha=0.75)

    # # ax_grid_dbm.plot_wireframe(XY_3d[:,0].reshape(GRID,GRID), XY_3d[:,1].reshape(GRID,GRID), XY_3d[:,2].reshape(GRID,GRID), colors=labels_color, alpha=0.5,)
    # ax.plot_surface(
    #     XY_3d[:,0].reshape(GRID,GRID), XY_3d[:,1].reshape(GRID,GRID), XY_3d[:,2].reshape(GRID,GRID), facecolors=labels_color_2d, #shade=False, #alpha=0.5, 
    #       linewidth=0.0, antialiased=False, rstride=1, cstride=1, )
    
    ########################### volume version plot##########
        # ax_grid_dbm.scatter(XY_3d[:,0], XY_3d[:,1], XY_3d[:,2], c=labels_color[:], alpha=0.9, marker='+', cmap = 'tab10', s=100)
    scatter2plot = blob0[0] * GRID
    ax.scatter(scatter2plot[:,0], scatter2plot[:,1], scatter2plot[:,2], c=blob0[1], cmap=CMAP, ec='k', s=7, linewidth=0.15, alpha=0.75)

    XY_3d *= GRID

    if not single_color:
        ax.plot_surface(
            XY_3d[:,0].reshape(GRID,GRID), XY_3d[:,1].reshape(GRID,GRID), XY_3d[:,2].reshape(GRID,GRID), facecolors=labels_color_2d, #shade=False, #alpha=0.5, 
            linewidth=0.0, antialiased=False, rstride=1, cstride=1, )
    else:
        # single color
        single_clor = (0.8, 0.8, 0.8, 0.6)
        single_cloer_2d = np.ones((GRID, GRID, 4))
        single_cloer_2d[:, :, 0] = single_clor[0]
        single_cloer_2d[:, :, 1] = single_clor[1]
        single_cloer_2d[:, :, 2] = single_clor[2]
        single_cloer_2d[:, :, 3] = single_clor[3]

        ax.plot_surface(
            XY_3d[:,0].reshape(GRID,GRID), XY_3d[:,1].reshape(GRID,GRID), XY_3d[:,2].reshape(GRID,GRID), facecolors=single_cloer_2d, ec=None, #shade=False, #alpha=0.5, 
              linewidth=0.0, antialiased=False, rstride=1, cstride=1, )
    
    ######################

    # ratio = 0.1
    # ax.set_xlim(blob0[0][:,0].min()+ratio, blob0[0][:,0].max()*.9)
    # ax.set_ylim(blob0[0][:,1].min()+ratio, blob0[0][:,1].max()*.9)
    # ax.set_zlim(blob0[0][:,2].min()+ratio, blob0[0][:,2].max()*.9)


    return ax, XY_3d

def adjust_ax(ax):
    # # Make panes transparent
    # ax.xaxis.pane.fill = False # Left pane
    # ax.yaxis.pane.fill = False # Right pane
    # ax.zaxis.pane.fill = False # Right pane

    ### Remove grid lines
    # ax.grid(False)

    ## Remove tick labels
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_zticklabels([])

    # ## Transparent spines
    # ax.w_xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
    # ax.w_yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
    # ax.w_zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))

    # ## Transparent panes
    # ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    # ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    # ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

    ## No ticks
    # ax.set_xticks([]) 
    # ax.set_yticks([]) 
    # ax.set_zticks([])

    # backgroud color
    ax.set_facecolor((0.95, 0.95, 0.95, 0.0))
    return ax

# plot_inverse_map(dbm)
# plt.show()


def empty_ax(ax):
        # Make panes transparent
    ax.xaxis.pane.fill = False # Left pane
    ax.yaxis.pane.fill = False # Right pane
    ax.zaxis.pane.fill = False # Right pane

    ## Remove grid lines
    ax.grid(False)

    ## Remove tick labels
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_zticklabels([])

    ## Transparent spines
    ax.w_xaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
    ax.w_yaxis.line.set_color((1.0, 1.0, 1.0, 0.0))
    ax.w_zaxis.line.set_color((1.0, 1.0, 1.0, 0.0))

    ## Transparent panes
    ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

    # No ticks
    ax.set_xticks([]) 
    ax.set_yticks([]) 
    ax.set_zticks([])

# %%
from skimage.measure import marching_cubes

def plot_volume2(clf, ax=None, grid=GRID, CMAP=CMAP, scatter=False, voxel=True, d_surface=False):
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')

    xx, yy, zz = np.meshgrid(np.linspace(blob0[0][:,0].min(), blob0[0][:,0].max(), grid),
                                np.linspace(blob0[0][:,1].min(), blob0[0][:,1].max(), grid),
                                np.linspace(blob0[0][:,2].min(), blob0[0][:,2].max(), grid))
    
    XYZ = np.c_[xx.ravel(), yy.ravel(), zz.ravel()]
    labels = clf.predict(XYZ)
    label_cube = labels.reshape(grid, grid, grid)

    # swap axis 
    label_cube = np.swapaxes(label_cube, 0, 1)
    

    cmap = cm.get_cmap(CMAP)
    labels_color_3d = cmap(label_cube/label_cube.max())
    # labels_color_3d = labels_color.reshape(grid, grid, grid, 4)
    labels_color_3d[:, :, :, 3] = 0.4
    voxels = np.ones((grid, grid, grid), dtype=bool)
    if voxel:
        ax.voxels(voxels, facecolors=labels_color_3d, linewidth=0.1, alpha=0.3, shade=False) #edgecolor='k', 

    # Use marching cubes to obtain the surface mesh
    verts, faces, normals, values = marching_cubes(label_cube, level=0.5)

    if d_surface:
        # Plotting the surface
        ax.plot_trisurf(verts[:, 0], verts[:, 1], verts[:, 2], triangles=faces, alpha=0.1, antialiased=True, color='#3322DD', edgecolor=None)

    if scatter:
        scatter2plot = blob0[0] * GRID
        ax.scatter(scatter2plot[:,0], scatter2plot[:,1], scatter2plot[:,2], c=blob0[1], cmap=CMAP, ec='k', s=7, linewidth=0.15, alpha=0.95)

    return ax, verts


def find_intersection(verts, XY_3d, tolerance=0.1):
    intersection_points = []
    for vertex in verts:
        distances = np.linalg.norm(XY_3d - vertex, axis=1)
        if np.any(distances < tolerance):
            intersection_points.append(vertex)
    return np.array(intersection_points)

# %%
# %matplotlib widget

# %%
# %matplotlib widget
GRID=20
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax, verts  = plot_volume2(clf, ax=ax, grid=GRID, CMAP=CMAP, d_surface=True, voxel=False )
ax, DM_3d = plot_inverse_map(rbf_inv, GRID=GRID, clf=clf, ax=ax, CMAP=CMAP, single_color=False)

# # Find intersection points
intersection_points = find_intersection(verts, DM_3d, tolerance=0.8)
print(intersection_points.shape)
# # Plot the intersection points
ax.scatter(intersection_points[:, 0], intersection_points[:, 1], intersection_points[:, 2], c='r', s=5, label='Intersection', marker='.')

# # set camera position
# ax.view_init(25, 144)
# # ax.view_init(30, 30)

# set axis label
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(40, 190)
# Out:
# Phi_new:  (400, 150)
# (40, 3)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)

# %%
# build a fig with 3 3d-axes
fig = plt.figure(figsize=(9,3.5))
ax1 = fig.add_subplot(131, projection='3d', )
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')
# white space between subplots
fig.subplots_adjust(wspace=0.0, hspace=0.0)

plot_inverse_map(dbm, ax=ax1)
plot_inverse_map(ssnp, ax=ax2)
plot_inverse_map(DV, ax=ax3)

# plot the volume
plot_volume2(clf, ax=ax1)
plot_volume2(clf, ax=ax2)
plot_volume2(clf, ax=ax3)



## set view angle
# viual_angle = (44, -44, 20)
# ax1.view_init(*viual_angle)
# ax2.view_init(*viual_angle)
# ax3.view_init(*viual_angle)

ax1.set_title('DBM (UMAP+NNinv)', fontsize=14)
ax2.set_title('SDBM', fontsize=14)
ax3.set_title('DeepView', fontsize=14)

# fig.savefig('./figures/3d_all.pdf', dpi=300, bbox_inches='tight')
# fig.savefig('../DecisionMap_Comapre_manuscript/figures/demo3d_new.pdf', dpi=300, bbox_inches='tight')
# Out:
# 5/5 [==============================] - 0s 0s/step
# 13/13 [==============================] - 0s 0s/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 1018.54it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Text(0.5, 0.92, 'DeepView')

# %%
# %matplotlib inline
classifiers = {
    'placeholder_clf': linear_model.LogisticRegression(),
    'Logistic Regression': linear_model.LogisticRegression(),
    'SVM': SVC(probability=True),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier([256,256,256]),
    'Decision Tree': DecisionTreeClassifier(),
    'KNN': KNeighborsClassifier(),
}

## fit the models
for name, clf in classifiers.items():
    clf.fit(X, y)
    
dms = {
    'placeholder': P_wrapper(),
    'DBM(MDS+NNinv)': dbm,
    'SDBM': ssnp,
    'DeepView': DV,
    'MDS+iLAMP': ilamp,
    'MDS+RBF': rbf_inv,
    'MDS+iMDS': mdsinv_rand,
}

# %%
## plot the figur, cols is number of dms+1, rows is number of classifiers+1
GRID = 15
d_surface = True

cols = len(dms) 
rows = len(classifiers)

# %%
# fig3d.savefig('./figures/3d_all.pdf', dpi=300, bbox_inches='tight')
# fig3d.savefig('../papers/IVAPP24_extend_CCIS/figures/figure_CCIS/IRIS3d_class02.png', dpi=300, bbox_inches='tight')

# %%
fig3d = plt.figure(figsize=(cols*3, rows*2.8))
fig3d.subplots_adjust(wspace=-0.56, hspace=-0.25)
fig3d.subplots_adjust(left=0, right=0.7, bottom=0, top=0.6)

for i, (clf_name, clf) in enumerate(classifiers.items()):
    for j, (dm_name, dm) in enumerate(dms.items()):
        # print(i, j)
        ax = fig3d.add_subplot(rows, cols, i*cols+j+1, projection='3d')
        adjust_ax(ax)
        if i == 0 and j == 0:
            ### show nothing, leave it blank
            ax.set_axis_off()
            continue
        if i == 0:
            # 3d plot
            
            plot_inverse_map(dm, ax=ax, clf=clf, single_color=True, GRID=GRID)
            ax.set_title(dm_name, fontsize=14, pad=0)

        elif j == 0:
            plot_volume2(clf, ax=ax, grid=GRID, CMAP=CMAP, scatter=True, voxel=True, d_surface=d_surface)
            # a label at the left of each row
            ax.text2D(-0., 0.5, clf_name, fontsize=13, transform=ax.transAxes, rotation=90, va='center', ha='center')
        else:
            if dm_name == 'DeepView':
                dm = P_wrapper(NNinv_Keras=0, NNinv_Torch=0, deepview=1, ssnp=0)
                dm.fit(X, y, clf)
            plot_inverse_map(P_inv=dm, ax=ax, clf=clf, single_color=False, GRID=GRID)
            plot_volume2(clf, ax=ax, grid=GRID, CMAP=CMAP, scatter=False, voxel=True, d_surface=d_surface)

        adjust_ax(ax)
        # ax.view_init(25, 144)
        # ax.view_init(35, 35)
        # ax.view_init(7, 35)
        ax.view_init(40, 155)
        ax.view_init(12, 142)
        ax.view_init(35, 192)
        ax.view_init(25, 190)
        ax.view_init(15, 190)
# fig.savefig('./figures/3d_all.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 5/5 [==============================] - 0s 4ms/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 8/8 [==============================] - 0s 2ms/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 992.08it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<?, ?it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 0s/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 1592.40it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# transforming
# fitting inverse
# done
# fitting time:  0.9851589202880859
# 100%|██████████| 150/150 [00:00<00:00, 1007.68it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<00:00, 40698.47it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 0s/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 187.55it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# done
# fitting time:  1.7302169799804688
# 100%|██████████| 150/150 [00:01<00:00, 101.87it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<?, ?it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 2ms/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:01<00:00, 120.05it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# transforming
# fitting inverse
# done
# fitting time:  2.2154154777526855
# 100%|██████████| 150/150 [00:01<00:00, 84.39it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<?, ?it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 836us/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 335.42it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# transforming
# fitting inverse
# done
# fitting time:  1.293684720993042
# 100%|██████████| 150/150 [00:00<00:00, 199.68it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<00:00, 220493.80it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 936us/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 2257.32it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# transforming
# fitting inverse
# done
# fitting time:  0.9180166721343994
# 100%|██████████| 150/150 [00:00<00:00, 999.53it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<?, ?it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 2ms/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 566.32it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# transforming
# fitting inverse
# done
# fitting time:  1.135791540145874
# 100%|██████████| 150/150 [00:00<00:00, 328.01it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 100%|██████████| 224/224 [00:00<00:00, 200239.58it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# Phi_new:  (225, 150)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)
# 225
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\48770605.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(CMAP)

# %%
# fig3d.savefig('../paper/PAPER_intrinsic_dim/figures/dm3d_all.png', dpi=300, bbox_inches='tight')
# fig3d.savefig('../paper/PAPER_intrinsic_dim/figures/dm3d_all.pdf', bbox_inches='tight')
# fig3d.savefig('../paper/PAPER_intrinsic_dim/figures/dm3d_all.eps', bbox_inches='tight')
# fig3d.savefig('../paper/PAPER_intrinsic_dim/figures/dm3d_all_iris.png', dpi=300, bbox_inches='tight')
# fig3d.savefig('figures/dm3d_iLAMP_RBF_blob.png', dpi=300, bbox_inches='tight')

# %%
# # swap axis 0 and 1 in figure 3d

# fig3d = plt.figure(figsize=(cols*3, rows*3))
# fig3d.subplots_adjust(wspace=0.0, hspace=0.0)

# for i, (clf_name, clf) in enumerate(classifiers.items()):
#     for j, (dm_name, dm) in enumerate(dms.items()):
#         # print(i, j)
#         ax = fig.add_subplot(rows, cols, i*cols+j+1, projection='3d')
#         adjust_ax(ax)
#         if i == 0 and j == 0:
#             continue
#         if i == 0:
#             # 3d plot
            
#             plot_inverse_map(dm, ax=ax, clf=clf, single_color=True, GRID=GRID)
#             ax.set_title(dm_name, fontsize=14)

#         elif j == 0:
#             plot_volume2(clf, ax=ax, grid=GRID, CMAP=CMAP, scatter=True, voxel=True, d_surface=False)
#             # a label at the left of each row
#             ax.text2D(-0.1, 0.5, clf_name, fontsize=13, transform=ax.transAxes, rotation=90, va='center', ha='center')
#         else:
#             plot_inverse_map(dm, ax=ax, clf=clf, single_color=False, GRID=GRID)
#             plot_volume2(clf, ax=ax, grid=GRID, CMAP=CMAP, scatter=False, voxel=True, d_surface=False)

#         adjust_ax(ax)
#         # ax.view_init(25, 144)
#         # ax.view_init(35, 35)
# # fig.savefig('./figures/dm3d_all_horizontal.png', dpi=300, bbox_inches='tight')

# %%
## 

fig, axes = plt.subplots(rows-1, cols-1, figsize=(cols*1.5, 10))
fig.subplots_adjust(wspace=0.0, hspace=0.0)

for i, (clf_name, clf) in enumerate(classifiers.items()):
    for j, (dm_name, dm) in enumerate(dms.items()):
        if i == 0 or j == 0:
            continue
        ax = axes[i-1, j-1]
        # sqaure aspect ratio
        ax.set_aspect('equal')
        # legend false
        if dm_name == 'DeepView':
                dm = P_wrapper(NNinv_Keras=0, NNinv_Torch=0, deepview=1, ssnp=0)
                dm.fit(X, y, clf)
        dm_holder = MapBuilder(clf, dm, X, y, grid=100) ## it was 300
        ax = dm_holder.plot_prob_map(ax=ax, proba=False, cmap=CMAP, epsilo=0.7)
        dm_holder.plot_training_data(ax=ax, cmap=CMAP, ec='k', lw=0.1, size=20)
        ax.legend_ = None
        if i == 1:
            ax.set_title(dm_name, fontsize=12)
        if j == 1:
            ax.set_ylabel(clf_name, fontsize=12, rotation=45, ha='right', va='center')
# plt.tight_layout()
# Out:
# calculating probability map
# 5/5 [==============================] - 0s 0s/step
# calculating probability map
# 313/313 [==============================] - 0s 757us/step
# 100%|██████████| 150/150 [00:00<00:00, 1851.90it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# done
# fitting time:  0.9488711357116699
# calculating probability map
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# calculating probability map
# 100%|██████████| 1999/1999 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 400105.31it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 409380.12it/s]
# 100%|██████████| 1997/1997 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# calculating probability map
# Phi_new:  (10000, 150)
# calculating probability map
# 10000
# (3,)
# (3,)
# calculating probability map
# 5/5 [==============================] - 0s 4ms/step
# calculating probability map
# 313/313 [==============================] - 0s 640us/step
# 100%|██████████| 150/150 [00:00<00:00, 217.42it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# done
# fitting time:  1.5605921745300293
# calculating probability map
# calculating probability map
# 100%|██████████| 1999/1999 [00:00<00:00, 361054.76it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# 100%|██████████| 1997/1997 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# calculating probability map
# Phi_new:  (10000, 150)
# calculating probability map
# 10000
# (3,)
# (3,)
# calculating probability map
# 5/5 [==============================] - 0s 0s/step
# calculating probability map
# 313/313 [==============================] - 0s 621us/step
# 100%|██████████| 150/150 [00:01<00:00, 126.00it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# done
# fitting time:  2.8455910682678223
# calculating probability map
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# calculating probability map
# 100%|██████████| 1999/1999 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 139840.43it/s]
# 100%|██████████| 1997/1997 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# calculating probability map
# Phi_new:  (10000, 150)
# calculating probability map
# 10000
# (3,)
# (3,)
# calculating probability map
# 5/5 [==============================] - 0s 1ms/step
# calculating probability map
# 313/313 [==============================] - 0s 692us/step
# 100%|██████████| 150/150 [00:00<00:00, 337.87it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# done
# fitting time:  1.300241470336914
# calculating probability map
# calculating probability map
# 100%|██████████| 1999/1999 [00:00<00:00, 118742.58it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 127661.06it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# 100%|██████████| 1997/1997 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# calculating probability map
# Phi_new:  (10000, 150)
# calculating probability map
# 10000
# (3,)
# (3,)
# calculating probability map
# 5/5 [==============================] - 0s 1ms/step
# calculating probability map
# 313/313 [==============================] - 0s 672us/step
# 100%|██████████| 150/150 [00:00<00:00, 1593.63it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# done
# fitting time:  0.9331352710723877
# calculating probability map
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# calculating probability map
# 100%|██████████| 1999/1999 [00:00<00:00, 116109.92it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 128537.40it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 135300.13it/s]
# 100%|██████████| 1997/1997 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# calculating probability map
# Phi_new:  (10000, 150)
# calculating probability map
# 10000
# (3,)
# (3,)
# calculating probability map
# 5/5 [==============================] - 0s 0s/step
# calculating probability map
# 313/313 [==============================] - 0s 704us/step
# 100%|██████████| 150/150 [00:00<00:00, 567.68it/s]
# updating matrices
# (0,) (150, 150)
# discr 0.0
# (0,) (150, 150)
# fitting mapper
# transforming
# fitting inverse
# done
# fitting time:  1.118373155593872
# calculating probability map
# C:\Users\yuwan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# calculating probability map
# 100%|██████████| 1999/1999 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# 100%|██████████| 2000/2000 [00:00<?, ?it/s]
# 100%|██████████| 1997/1997 [00:00<00:00, 123737.30it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 128027.35it/s]
# calculating probability map
# Phi_new:  (10000, 150)
# calculating probability map
# 10000
# (3,)
# (3,)

# %%
# fig.savefig('../paper/PAPER_intrinsic_dim/figures/dm2d_all.png', dpi=300, bbox_inches='tight')
# # fig.savefig('../paper/PAPER_intrinsic_dim/figures/dm2d_all_iris.png', dpi=300, bbox_inches='tight')
# fig.savefig('figures/dm2d_iLAMP_RBF_blob.png', dpi=300, bbox_inches='tight')

# %%
# %matplotlib inline
GRID = 50

dms = {
    # 'placeholder': P_wrapper(),
    'DBM(MDS+NNinv)': dbm,
    'SDBM': ssnp,
    'DeepView': DV,
    'MDS+iLAMP': ilamp,
    'MDS+RBF': rbf_inv,
    'MDS+iMDS': mdsinv_rand,
}

clf = classifiers['Logistic Regression']
fig3d = plt.figure(figsize=(cols*3, 3*2.8))
fig3d.subplots_adjust(wspace=-0.18, hspace=-0.16)
# fig3d.subplots_adjust(left=0, right=0.7, bottom=0, top=0.6)
view_angles = [(25, 150), (20, 270), ] # (20, 150), (30, 210),
for i in range(2):
    for j, (dm_name, dm) in enumerate(dms.items()):
        ax = fig3d.add_subplot(3, cols, i*cols+j+1, projection='3d')
        if i == 0:
            ax.set_title(dm_name, fontsize=14, pad=-1)
        # if j == 0:
        #     ax.set_ylabel(name, fontsize=14)
        # if i == 0:
            # plot_volume2(clf, ax=ax, grid=GRID, CMAP=CMAP, d_surface=d_surface, voxel=False)
        plot_inverse_map(P_inv=dm, ax=ax, clf=clf, single_color=False, GRID=GRID, ) #CMAP='viridis'
        ax = adjust_ax(ax)
        ## set lim
        ax.set_xlim(-10, 55)
        ax.set_ylim(-10, 55)
        ax.set_zlim(-10, 55)

        ax.view_init(*view_angles[i])
# Out:
# 5/5 [==============================] - 0s 0s/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 79/79 [==============================] - 0s 668us/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 991.60it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 1998/1998 [00:00<00:00, 499714.93it/s]
# 100%|██████████| 499/499 [00:00<?, ?it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# Phi_new:  (2500, 150)
# 2500
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 5/5 [==============================] - 0s 1ms/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 79/79 [==============================] - 0s 642us/step
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 150/150 [00:00<00:00, 1029.34it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# 100%|██████████| 1998/1998 [00:00<?, ?it/s]
# 100%|██████████| 499/499 [00:00<?, ?it/s]
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)
# Phi_new:  (2500, 150)
# 2500
# (3,)
# (3,)
# C:\Users\yuwan\AppData\Local\Temp\ipykernel_10180\1606454996.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   tab10 = cm.get_cmap(CMAP)

# %%
fig3d.savefig('./figures/3d_all.pdf', dpi=300, bbox_inches='tight')
fig3d.savefig('../papers/IVAPP24_extend_CCIS/figures/figure_CCIS/IRIS3d_class012.png', dpi=300, bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, cols-1, figsize=(cols*1.7, 2))
fig.subplots_adjust(wspace=0.0, hspace=0.0)


for j, (dm_name, dm) in enumerate(dms.items()):
    ax = axes[j]
    # sqaure aspect ratio
    ax.set_aspect('equal')
    # legend false
    dm_holder = MapBuilder(clf, dm, X, y, grid=50) ## it was 300
    ax = dm_holder.plot_prob_map(ax=ax, proba=False, cmap=CMAP, epsilo=0.7)
    dm_holder.plot_training_data(ax=ax, cmap=CMAP, ec='k', lw=0.1, size=20)
    ax.legend_ = None
    ax.set_title(dm_name, fontsize=12)
    ax.set_aspect('equal')
    # if j == 1:
        # ax.set_ylabel(clf_name, fontsize=12, rotation=45, ha='right', va='center')
# Out:
# calculating probability map
# 5/5 [==============================] - 0s 1ms/step
# calculating probability map
# 79/79 [==============================] - 0s 665us/step
# calculating probability map
# calculating probability map
# 100%|██████████| 1998/1998 [00:00<00:00, 1509405.51it/s]
# 100%|██████████| 499/499 [00:00<?, ?it/s]
# calculating probability map
# Phi_new:  (2500, 150)
# calculating probability map
# 2500
# (3,)
# (3,)
